# %% [markdown]
# ### Authors and Institutions

# %%
# give sql language

auth_docu ='''
select full_name, title, count(title)
from authors a, documents b, documents_authors c
where a.id=c.authors_id and c.documents_id=b.id
group by full_name
order by count(title) desc;
'''

auth_key = '''
select full_name, keyword, count(keyword)
from authors a, documents b, documents_authors c, keywords k, documents_keywords kd
where a.id=c.authors_id and c.documents_id=b.id and k.id=kd.keyword_id and b.id = kd.keyword_id
group by full_name
order by count(keyword) desc;
'''

auth_inst = '''
select institution, full_name, count(full_name)
from authors
group by institution
order by count(full_name) desc;
'''

inst_docu = '''
select institution, title, count(title)
from authors a, documents b, documents_authors c
where a.id=c.authors_id and b.id=c.documents_id
group by institution
order by count(title) desc;
'''


inst_key ='''
select distinct institution, keyword, count(keyword)
from authors a, documents b, documents_authors c, keywords k, documents_keywords kd
where a.id=c.authors_id and c.documents_id=b.id and k.id=kd.keyword_id and b.id = kd.keyword_id
group by institution
order by count(keyword) desc;
'''

auth_na_inst = '''
select institution, full_name
from authors
where institution = '';
'''

# %% [markdown]
# ### Documents

# %%
document_authors = '''
select title, full_name, count(full_name)
from authors a, documents_authors b, documents c
where a.id=b.authors_id and c.id = b.documents_id
group by title
order by count(full_name) desc
'''


# the documents from "author" ---"MIS//Qurterly"
MISQ_docu = '''
select title 
from documents, documents_authors b, authors c
where documents.id=b.documents_id and c.id=b.authors_id and c.full_name= "MIS//Quarterly"
'''

# %% [markdown]
# ### Keywords

# %%
#keywords and document (which keyword has max documents)

keywords_documents = '''
select keyword, title, article_id, count(title)
from documents doc, documents_keywords dk, keywords kw
where doc.id=dk.documents_id and  kw.id=dk.keyword_id
group by keyword
order by count(title) desc
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, Series
import networkx as nx
import itertools
import sqlite3

# %%
con = sqlite3.connect("data.sqlite")

# %%
auth_key_mod = '''
select full_name, keyword
from authors a, documents b, documents_authors c, keywords k, documents_keywords kd
where a.id=c.authors_id and c.documents_id=b.id and k.id=kd.keyword_id and b.id = kd.keyword_id;
'''

# %%
X = pd.read_sql(auth_key_mod, con)

# %%
X
# Out:
#                  full_name                             keyword
# 0           Gerald//Matlin          Collaborative telelearning
# 1              A.//Jenkins        technology mediated learning
# 2         Randall//Johnson        technology mediated learning
# 3        Alfonso//Cardenas           desktop videoconferencing
# 4        Alfonso//Cardenas           desktop videoconferencing
# 5          Robert//Bostrom          collaborative work ssytems
# 6               J.//Heinen          collaborative work ssytems
# 7           James//Johnson            IT in business education
# 8           Kenneth//Kozar            IT in business education
# 9              David//Ruch            IT in business education
# 10              Rob//Kling            Data resource management
# 11            I.//Benbasat              distributed processing
# 12           R.//Schroeder              distributed processing
# 13           Jim//Wetherbe               distributed databases
# 14      Carlton//Whitehead               distributed databases
# 15               Peter//B.                         gestalt fit
# 16           Eric//Carlson                    cluster analysis
# 17           Eric//Carlson                    cluster analysis
# 18          Barbara//Grace                    cluster analysis
# 19          Barbara//Grace                    cluster analysis
# 20           Jimmy//Sutton                    cluster analysis
# 21           Jimmy//Sutton                    cluster analysis
# 22              C.W.//Getz                            autonomy
# 23              C.W.//Getz                            autonomy
# 24              C.W.//Getz                            autonomy
# 25          Hugh//Juergens                      centralization
# 26          Hugh//Juergens                      centralization
# 27         James//Danziger           intersite data dependence
# 28           Malcom//Munro                        media choice
# 29           Gordon//Davis                        media choice
# ...                    ...                                 ...
# 4168       Andrew//Boynton                      Internet fraud
# 4169              Omar//El         statistical learning theory
# 4170     Sirkka//Jarvenpaa              website classification
# 4171         Gary//Dickson              website classification
# 4172  Gerardine//DeSanctis              website classification
# 4173       John//Henderson  Information systems security (ISS)
# 4174      David//Schilling  Information systems security (ISS)
# 4175    Ananth//Srinivasan               ISS de jure standards
# 4176      Robert//Benjamin                  politics and power
# 4177    Charles//Dickinson                  politics and power
# 4178      James//Kraushaar                   circuits of power
# 4179       Larry//Shirland                   circuits of power
# 4180        Beverely//Kahn                          resistance
# 4181    Nicholas//Vitalari                               norms
# 4182    Margaret//Rathwell                institutionalization
# 4183           Alan//Burns                institutionalization
# 4184         Nick//Rackoff           canonical action research
# 4185        Charles//Ph.D.           canonical action research
# 4186      R.A.//Hirschheim               Neutralization theory
# 4187        Marius//Janson                   deterrence theory
# 4188        Marius//Janson                   deterrence theory
# 4189             L.//Smith                   deterrence theory
# 4190             L.//Smith                   deterrence theory
# 4191       Mark//Gillenson                IS security policies
# 4192             Sid//Huff                         IS security
# 4193             Sid//Huff                         IS security
# 4194         Malcom//Munro                         IS security
# 4195         Malcom//Munro                         IS security
# 4196         Jack//Baroudi                          compliance
# 4197         Jack//Baroudi                          compliance
#
# [4198 rows x 2 columns]

# %%
auth_docu_mod ='''
select full_name, title
from authors a, documents b, documents_authors c
where a.id=c.authors_id and c.documents_id=b.id;
'''

# %%
Q = pd.read_sql(auth_docu_mod, con)

# %%
Q
# Out:
#                  full_name                                              title
# 0           Gerald//Matlin             How to Survive a Management Assessment
# 1              A.//Jenkins  What the Information Analyst Should Know About...
# 2         Randall//Johnson  What the Information Analyst Should Know About...
# 3        Alfonso//Cardenas  Technology for the Automatic Generation of App...
# 4          Robert//Bostrom  MIS Problems and Failures: A Socio-Technical P...
# 5               J.//Heinen  MIS Problems and Failures: A Socio-Technical P...
# 6           James//Johnson    RAFT: An Information System for Fiscal Analysis
# 7           Kenneth//Kozar    RAFT: An Information System for Fiscal Analysis
# 8              David//Ruch    RAFT: An Information System for Fiscal Analysis
# 9               Rob//Kling  The Organizational Context of User-Centered So...
# 10            I.//Benbasat  An Experimental Investigation of Some MIS Desi...
# 11           R.//Schroeder  An Experimental Investigation of Some MIS Desi...
# 12           Jim//Wetherbe  A Contingency View of Managing the Data Proces...
# 13      Carlton//Whitehead  A Contingency View of Managing the Data Proces...
# 14               Peter//B.    Transfer Pricing Management Information Systems
# 15           Eric//Carlson  Case Studies of End User Requirements for Inte...
# 16          Barbara//Grace  Case Studies of End User Requirements for Inte...
# 17           Jimmy//Sutton  Case Studies of End User Requirements for Inte...
# 18              C.W.//Getz  Coalescence: The Inevitable Fate of Data Proce...
# 19          Hugh//Juergens       Attributes of Information System Development
# 20         James//Danziger       Computers and the Frustrated Chief Executive
# 21           Malcom//Munro  Determining Management Information Needs: A Co...
# 22           Gordon//Davis  Determining Management Information Needs: A Co...
# 23         Robert//Bostrom  MIS Problems and Failures: A Socio-Technical P...
# 24              J.//Heinen  MIS Problems and Failures: A Socio-Technical P...
# 25    Gerardine//DeSanctis  Human Resource Information Systems: A Current ...
# 26          Charles//Franz  User Response to an Online Information System:...
# 27           Daniel//Robey  User Response to an Online Information System:...
# 28        Robert//Koeblitz  User Response to an Online Information System:...
# 29         A.R.//Montazemi  The Use of Cognitive Mapping for Information R...
# ...                    ...                                                ...
# 2727        Donald//Ballou  Reconciliation Process for Data Management in ...
# 2728            Giri//Tayi  Reconciliation Process for Data Management in ...
# 2729           Elie//Harel  The Effects of Using a Nonprocedural Computer ...
# 2730       Ephraim//McLean  The Effects of Using a Nonprocedural Computer ...
# 2731        Michael//Shank  Critical Success Factor Analysis as a Methodol...
# 2732       Andrew//Boynton  Critical Success Factor Analysis as a Methodol...
# 2733              Omar//El  Implementation by Cultural Infusion: An Approa...
# 2734     Sirkka//Jarvenpaa  Methodological Issues in Experimental IS Resea...
# 2735         Gary//Dickson  Methodological Issues in Experimental IS Resea...
# 2736  Gerardine//DeSanctis  Methodological Issues in Experimental IS Resea...
# 2737       John//Henderson  Design and Implementation of Decision Support ...
# 2738      David//Schilling  Design and Implementation of Decision Support ...
# 2739    Ananth//Srinivasan  Alternative Measures of System Effectiveness: ...
# 2740      Robert//Benjamin  Changing Role of the Corporate Information Sys...
# 2741    Charles//Dickinson  Changing Role of the Corporate Information Sys...
# 2742      James//Kraushaar  A Prototyping Method for Applications Developm...
# 2743       Larry//Shirland  A Prototyping Method for Applications Developm...
# 2744        Beverely//Kahn  An Environmentally Dependent Framework for Dat...
# 2745    Nicholas//Vitalari  Knowledge as a Basis for Expertise in Systems ...
# 2746    Margaret//Rathwell  Information Systems Support for Group Planning...
# 2747           Alan//Burns  Information Systems Support for Group Planning...
# 2748         Nick//Rackoff  Information Systems for Competitive Advantage:...
# 2749        Charles//Ph.D.  Information Systems for Competitive Advantage:...
# 2750      R.A.//Hirschheim  User Experience with and Assessment of Partici...
# 2751        Marius//Janson  Prototyping for Systems Development: A Critica...
# 2752             L.//Smith  Prototyping for Systems Development: A Critica...
# 2753       Mark//Gillenson                      Trends in Data Administration
# 2754             Sid//Huff  Information Technology Assessment and Adoption...
# 2755         Malcom//Munro  Information Technology Assessment and Adoption...
# 2756         Jack//Baroudi  The Impact of Role Variables on IS Personnel W...
#
# [2757 rows x 2 columns]
